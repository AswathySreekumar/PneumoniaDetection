# %%
# !pip install tensorflow-gpu

# %%
img_width=224
img_height=224
train_data_dir='/content/drive/MyDrive/Datasets/chestxray/train'
val_data_dir='/content/drive/MyDrive/Datasets/chestxray/val'

epochs=40

batch_size=32

# %%
from tensorflow.keras.applications.resnet_v2 import ResNet152V2,preprocess_input

basemdlresnet=ResNet152V2()
basemdlresnet.summary()
# Out:
# Model: "resnet152v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# ...

# %%
basemdlresnet=ResNet152V2(weights='imagenet',input_shape=(img_width,img_height,3),include_top=False)
basemdlresnet.summary()
# Out:
# Model: "resnet152v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# ...

# %%
for lyr in basemdlresnet.layers:
  lyr.trainable=False

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Model

# %%
x=basemdlresnet.output

x=Dense(1024,activation='relu')(x)
x=Dense(1024,activation='relu')(x)

x=Flatten()(x)

x=Dense(512,activation='relu')(x)
x=layers.Dropout(0.5)(x)

x=Dense(2,activation='softmax')(x)

# %%
mymdl=Model(basemdlresnet.input,x)

# %%
mymdl.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
import glob
numfolders=glob.glob('/content/drive/MyDrive/Datasets/chestxray/train/*')
len(numfolders)
# Out:
# 2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(preprocessing_function=preprocess_input,
                                 rescale=1/255,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 brightness_range=(0.1,0.5),
                                 horizontal_flip=True)

# %%
val_datagen=ImageDataGenerator(rescale=1./255)

# %%
training_set=train_datagen.flow_from_directory(train_data_dir,
                                               target_size=(img_width,img_height),
                                               batch_size=batch_size,
                                               class_mode='categorical')
# Out:
# Found 2412 images belonging to 2 classes.

# %%
training_set.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
val_set=val_datagen.flow_from_directory(val_data_dir,
                                        target_size=(img_width,img_height),
                                        batch_size=batch_size,
                                        class_mode='categorical')
# Out:
# Found 726 images belonging to 2 classes.

# %%
val_set.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
# !pip install pillow==4.0.0

# %%
mdl=mymdl.fit(training_set,
              validation_data=val_set,
              epochs=epochs,
              steps_per_epoch=len(training_set),
              validation_steps=len(val_set))
# Out:
# Epoch 1/40
# 76/76 [==============================] - 1255s 16s/step - loss: 0.8056 - accuracy: 0.5759 - val_loss: 0.7614 - val_accuracy: 0.4931
# Epoch 2/40
# 76/76 [==============================] - 1056s 14s/step - loss: 0.6138 - accuracy: 0.6567 - val_loss: 0.7118 - val_accuracy: 0.4945
# Epoch 3/40
# 76/76 [==============================] - 1037s 14s/step - loss: 0.5745 - accuracy: 0.6986 - val_loss: 0.6893 - val_accuracy: 0.4945
# Epoch 4/40
# 76/76 [==============================] - 1046s 14s/step - loss: 0.5516 - accuracy: 0.7052 - val_loss: 0.7180 - val_accuracy: 0.4904
# Epoch 5/40
# 76/76 [==============================] - 1046s 14s/step - loss: 0.4853 - accuracy: 0.7695 - val_loss: 0.7535 - val_accuracy: 0.4793
# Epoch 6/40
# 76/76 [==============================] - 1033s 14s/step - loss: 0.4792 - accuracy: 0.7716 - val_loss: 0.7926 - val_accuracy: 0.4793
# Epoch 7/40
# ...
